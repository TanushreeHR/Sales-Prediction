# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split

# %%
train_data = pd.read_csv('train.csv')
test_data = pd.read_csv('test.csv')

# %%
train_data['source'] = 'train'
test_data['source'] = 'test'

# %%
data = pd.concat([train_data, test_data], ignore_index=True)

# %% [markdown]
# Handling Missing Values

# %%
item_avg_weight = data.groupby('Item_Identifier')['Item_Weight'].transform('mean')
data['Item_Weight'].fillna(item_avg_weight, inplace=True)
data
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0               FDA15         9.30          Low Fat         0.016047
# 1               DRC01         5.92          Regular         0.019278
# 2               FDN15        17.50          Low Fat         0.016760
# 3               FDX07        19.20          Regular         0.000000
# 4               NCD19         8.93          Low Fat         0.000000
# ...               ...          ...              ...              ...
# 14199           FDB58        10.50          Regular         0.013496
# 14200           FDD47         7.60          Regular         0.142991
# 14201           NCO17        10.00          Low Fat         0.073529
# 14202           FDJ26        15.30          Regular         0.000000
# 14203           FDU37         9.50          Regular         0.104720
#
#                    Item_Type  Item_MRP Outlet_Identifier  \
# 0                      Dairy  249.8092            OUT049
# 1                Soft Drinks   48.2692            OUT018
# 2                       Meat  141.6180            OUT049
# 3      Fruits and Vegetables  182.0950            OUT010
# 4                  Household   53.8614            OUT013
# ...                      ...       ...               ...
# 14199            Snack Foods  141.3154            OUT046
# 14200          Starchy Foods  169.1448            OUT018
# 14201     Health and Hygiene  118.7440            OUT045
# 14202                 Canned  214.6218            OUT017
# 14203                 Canned   79.7960            OUT045
#
#        Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                           1999      Medium               Tier 1
# 1                           2009      Medium               Tier 3
# 2                           1999      Medium               Tier 1
# 3                           1998         NaN               Tier 3
# 4                           1987        High               Tier 3
# ...                          ...         ...                  ...
# 14199                       1997       Small               Tier 1
# 14200                       2009      Medium               Tier 3
# 14201                       2002         NaN               Tier 2
# 14202                       2007         NaN               Tier 2
# 14203                       2002         NaN               Tier 2
#
#              Outlet_Type  Item_Outlet_Sales source
# 0      Supermarket Type1          3735.1380  train
# 1      Supermarket Type2           443.4228  train
# 2      Supermarket Type1          2097.2700  train
# 3          Grocery Store           732.3800  train
# 4      Supermarket Type1           994.7052  train
# ...                  ...                ...    ...
# 14199  Supermarket Type1                NaN   test
# 14200  Supermarket Type2                NaN   test
# 14201  Supermarket Type1                NaN   test
# 14202  Supermarket Type1                NaN   test
# 14203  Supermarket Type1                NaN   test
#
# [14204 rows x 13 columns]

# %%
data.isnull().sum() # handled item weight missing values, ignore sales as it is in test data
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  4016
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales            5681
# source                          0
# dtype: int64

# %%
outlet_size_mode = data.pivot_table(values='Outlet_Size', columns='Outlet_Type', 
                                    aggfunc=lambda x: x.mode()[0] if not x.mode().empty else np.nan)
outlet_size_mode
# Out:
# Outlet_Type Grocery Store Supermarket Type1 Supermarket Type2  \
# Outlet_Size         Small             Small            Medium
#
# Outlet_Type Supermarket Type3
# Outlet_Size            Medium

# %%
def impute_size(row):
    if pd.isnull(row['Outlet_Size']):
        return outlet_size_mode[row['Outlet_Type']]
    else:
        return row['Outlet_Size']
    
data['Outlet_Size'] = data.apply(impute_size, axis=1)
data.isnull().sum() # handled outlet size missing values
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                     0
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales            5681
# source                          0
# dtype: int64

# %% [markdown]
# Standardizing the values

# %%
data['Item_Fat_Content'] = data['Item_Fat_Content'].replace({
    'low fat': 'Low Fat',
    'LF': 'Low Fat',
    'reg': 'Regular'
})

# %%
#zero visibility values
visibility_means = data.groupby('Item_Type')['Item_Visibility'].transform('mean')
# Replace 0 visibility values with the mean of their respective Item_Type
zero_indices = data['Item_Visibility'] == 0
data.loc[zero_indices, 'Item_Visibility'] = visibility_means[zero_indices]
data
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0               FDA15         9.30          Low Fat         0.016047
# 1               DRC01         5.92          Regular         0.019278
# 2               FDN15        17.50          Low Fat         0.016760
# 3               FDX07        19.20          Regular         0.068571
# 4               NCD19         8.93          Low Fat         0.059716
# ...               ...          ...              ...              ...
# 14199           FDB58        10.50          Regular         0.013496
# 14200           FDD47         7.60          Regular         0.142991
# 14201           NCO17        10.00          Low Fat         0.073529
# 14202           FDJ26        15.30          Regular         0.067836
# 14203           FDU37         9.50          Regular         0.104720
#
#                    Item_Type  Item_MRP Outlet_Identifier  \
# 0                      Dairy  249.8092            OUT049
# 1                Soft Drinks   48.2692            OUT018
# 2                       Meat  141.6180            OUT049
# 3      Fruits and Vegetables  182.0950            OUT010
# 4                  Household   53.8614            OUT013
# ...                      ...       ...               ...
# 14199            Snack Foods  141.3154            OUT046
# 14200          Starchy Foods  169.1448            OUT018
# 14201     Health and Hygiene  118.7440            OUT045
# 14202                 Canned  214.6218            OUT017
# 14203                 Canned   79.7960            OUT045
#
#        Outlet_Establishment_Year  \
# 0                           1999
# 1                           2009
# 2                           1999
# 3                           1998
# 4                           1987
# ...                          ...
# 14199                       1997
# 14200                       2009
# 14201                       2002
# 14202                       2007
# 14203                       2002
#
#                                              Outlet_Size Outlet_Location_Type  \
# 0                                                 Medium               Tier 1
# 1                                                 Medium               Tier 3
# 2                                                 Medium               Tier 1
# 3      Outlet_Size    Small
# Name: Grocery Store, dtyp...               Tier 3
# 4                                                   High               Tier 3
# ...                                                  ...                  ...
# 14199                                              Small               Tier 1
# 14200                                             Medium               Tier 3
# 14201  Outlet_Size    Small
# Name: Supermarket Type1, ...               Tier 2
# 14202  Outlet_Size    Small
# Name: Supermarket Type1, ...               Tier 2
# 14203  Outlet_Size    Small
# Name: Supermarket Type1, ...               Tier 2
#
#              Outlet_Type  Item_Outlet_Sales source
# 0      Supermarket Type1          3735.1380  train
# 1      Supermarket Type2           443.4228  train
# 2      Supermarket Type1          2097.2700  train
# 3          Grocery Store           732.3800  train
# 4      Supermarket Type1           994.7052  train
# ...                  ...                ...    ...
# 14199  Supermarket Type1                NaN   test
# 14200  Supermarket Type2                NaN   test
# 14201  Supermarket Type1                NaN   test
# 14202  Supermarket Type1                NaN   test
# 14203  Supermarket Type1                NaN   test
#
# [14204 rows x 13 columns]

# %%
(data['Item_Visibility'] == 0).sum()
# Out:
# 0

# %%
data['Item_Category'] = data['Item_Identifier'].apply(lambda x: x[:2])
# Map to meaningful categories
data['Item_Category'] = data['Item_Category'].map({
    'FD': 'Food',
    'DR': 'Drinks',
    'NC': 'Non-Consumable'
})
data
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0               FDA15         9.30          Low Fat         0.016047
# 1               DRC01         5.92          Regular         0.019278
# 2               FDN15        17.50          Low Fat         0.016760
# 3               FDX07        19.20          Regular         0.068571
# 4               NCD19         8.93          Low Fat         0.059716
# ...               ...          ...              ...              ...
# 14199           FDB58        10.50          Regular         0.013496
# 14200           FDD47         7.60          Regular         0.142991
# 14201           NCO17        10.00          Low Fat         0.073529
# 14202           FDJ26        15.30          Regular         0.067836
# 14203           FDU37         9.50          Regular         0.104720
#
#                    Item_Type  Item_MRP Outlet_Identifier  \
# 0                      Dairy  249.8092            OUT049
# 1                Soft Drinks   48.2692            OUT018
# 2                       Meat  141.6180            OUT049
# 3      Fruits and Vegetables  182.0950            OUT010
# 4                  Household   53.8614            OUT013
# ...                      ...       ...               ...
# 14199            Snack Foods  141.3154            OUT046
# 14200          Starchy Foods  169.1448            OUT018
# 14201     Health and Hygiene  118.7440            OUT045
# 14202                 Canned  214.6218            OUT017
# 14203                 Canned   79.7960            OUT045
#
#        Outlet_Establishment_Year  \
# 0                           1999
# 1                           2009
# 2                           1999
# 3                           1998
# 4                           1987
# ...                          ...
# 14199                       1997
# 14200                       2009
# 14201                       2002
# 14202                       2007
# 14203                       2002
#
#                                              Outlet_Size Outlet_Location_Type  \
# 0                                                 Medium               Tier 1
# 1                                                 Medium               Tier 3
# 2                                                 Medium               Tier 1
# 3      Outlet_Size    Small
# Name: Grocery Store, dtyp...               Tier 3
# 4                                                   High               Tier 3
# ...                                                  ...                  ...
# 14199                                              Small               Tier 1
# 14200                                             Medium               Tier 3
# 14201  Outlet_Size    Small
# Name: Supermarket Type1, ...               Tier 2
# 14202  Outlet_Size    Small
# Name: Supermarket Type1, ...               Tier 2
# 14203  Outlet_Size    Small
# Name: Supermarket Type1, ...               Tier 2
#
#              Outlet_Type  Item_Outlet_Sales source   Item_Category
# 0      Supermarket Type1          3735.1380  train            Food
# 1      Supermarket Type2           443.4228  train          Drinks
# 2      Supermarket Type1          2097.2700  train            Food
# 3          Grocery Store           732.3800  train            Food
# 4      Supermarket Type1           994.7052  train  Non-Consumable
# ...                  ...                ...    ...             ...
# 14199  Supermarket Type1                NaN   test            Food
# 14200  Supermarket Type2                NaN   test            Food
# 14201  Supermarket Type1                NaN   test  Non-Consumable
# 14202  Supermarket Type1                NaN   test            Food
# 14203  Supermarket Type1                NaN   test            Food
#
# [14204 rows x 14 columns]

# %%
data['Outlet_Age'] = 2013 - data['Outlet_Establishment_Year']
data
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0               FDA15         9.30          Low Fat         0.016047
# 1               DRC01         5.92          Regular         0.019278
# 2               FDN15        17.50          Low Fat         0.016760
# 3               FDX07        19.20          Regular         0.068571
# 4               NCD19         8.93          Low Fat         0.059716
# ...               ...          ...              ...              ...
# 14199           FDB58        10.50          Regular         0.013496
# 14200           FDD47         7.60          Regular         0.142991
# 14201           NCO17        10.00          Low Fat         0.073529
# 14202           FDJ26        15.30          Regular         0.067836
# 14203           FDU37         9.50          Regular         0.104720
#
#                    Item_Type  Item_MRP Outlet_Identifier  \
# 0                      Dairy  249.8092            OUT049
# 1                Soft Drinks   48.2692            OUT018
# 2                       Meat  141.6180            OUT049
# 3      Fruits and Vegetables  182.0950            OUT010
# 4                  Household   53.8614            OUT013
# ...                      ...       ...               ...
# 14199            Snack Foods  141.3154            OUT046
# 14200          Starchy Foods  169.1448            OUT018
# 14201     Health and Hygiene  118.7440            OUT045
# 14202                 Canned  214.6218            OUT017
# 14203                 Canned   79.7960            OUT045
#
#        Outlet_Establishment_Year  \
# 0                           1999
# 1                           2009
# 2                           1999
# 3                           1998
# 4                           1987
# ...                          ...
# 14199                       1997
# 14200                       2009
# 14201                       2002
# 14202                       2007
# 14203                       2002
#
#                                              Outlet_Size Outlet_Location_Type  \
# 0                                                 Medium               Tier 1
# 1                                                 Medium               Tier 3
# 2                                                 Medium               Tier 1
# 3      Outlet_Size    Small
# Name: Grocery Store, dtyp...               Tier 3
# 4                                                   High               Tier 3
# ...                                                  ...                  ...
# 14199                                              Small               Tier 1
# 14200                                             Medium               Tier 3
# 14201  Outlet_Size    Small
# Name: Supermarket Type1, ...               Tier 2
# 14202  Outlet_Size    Small
# Name: Supermarket Type1, ...               Tier 2
# 14203  Outlet_Size    Small
# Name: Supermarket Type1, ...               Tier 2
#
#              Outlet_Type  Item_Outlet_Sales source   Item_Category  Outlet_Age
# 0      Supermarket Type1          3735.1380  train            Food          14
# 1      Supermarket Type2           443.4228  train          Drinks           4
# 2      Supermarket Type1          2097.2700  train            Food          14
# 3          Grocery Store           732.3800  train            Food          15
# 4      Supermarket Type1           994.7052  train  Non-Consumable          26
# ...                  ...                ...    ...             ...         ...
# 14199  Supermarket Type1                NaN   test            Food          16
# 14200  Supermarket Type2                NaN   test            Food           4
# 14201  Supermarket Type1                NaN   test  Non-Consumable          11
# 14202  Supermarket Type1                NaN   test            Food           6
# 14203  Supermarket Type1                NaN   test            Food          11
#
# [14204 rows x 15 columns]

# %%
data['Outlet_Age_Bin'] = pd.cut(
    data['Outlet_Age'], 
    bins=[0, 5, 10, 15, 20, 30], 
    labels=['0-5', '6-10', '11-15', '16-20', '20+']
)

# %%
data['Item_MRP_Bin'] = pd.cut(
    data['Item_MRP'], 
    bins=[0, 50, 100, 150, 200, 300], 
    labels=['0-50', '50-100', '100-150', '150-200', '200+']
)

# %%
data
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0               FDA15         9.30          Low Fat         0.016047
# 1               DRC01         5.92          Regular         0.019278
# 2               FDN15        17.50          Low Fat         0.016760
# 3               FDX07        19.20          Regular         0.068571
# 4               NCD19         8.93          Low Fat         0.059716
# ...               ...          ...              ...              ...
# 14199           FDB58        10.50          Regular         0.013496
# 14200           FDD47         7.60          Regular         0.142991
# 14201           NCO17        10.00          Low Fat         0.073529
# 14202           FDJ26        15.30          Regular         0.067836
# 14203           FDU37         9.50          Regular         0.104720
#
#                    Item_Type  Item_MRP Outlet_Identifier  \
# 0                      Dairy  249.8092            OUT049
# 1                Soft Drinks   48.2692            OUT018
# 2                       Meat  141.6180            OUT049
# 3      Fruits and Vegetables  182.0950            OUT010
# 4                  Household   53.8614            OUT013
# ...                      ...       ...               ...
# 14199            Snack Foods  141.3154            OUT046
# 14200          Starchy Foods  169.1448            OUT018
# 14201     Health and Hygiene  118.7440            OUT045
# 14202                 Canned  214.6218            OUT017
# 14203                 Canned   79.7960            OUT045
#
#        Outlet_Establishment_Year  \
# 0                           1999
# 1                           2009
# 2                           1999
# 3                           1998
# 4                           1987
# ...                          ...
# 14199                       1997
# 14200                       2009
# 14201                       2002
# 14202                       2007
# 14203                       2002
#
#                                              Outlet_Size Outlet_Location_Type  \
# 0                                                 Medium               Tier 1
# 1                                                 Medium               Tier 3
# 2                                                 Medium               Tier 1
# 3      Outlet_Size    Small
# Name: Grocery Store, dtyp...               Tier 3
# 4                                                   High               Tier 3
# ...                                                  ...                  ...
# 14199                                              Small               Tier 1
# 14200                                             Medium               Tier 3
# 14201  Outlet_Size    Small
# Name: Supermarket Type1, ...               Tier 2
# 14202  Outlet_Size    Small
# Name: Supermarket Type1, ...               Tier 2
# 14203  Outlet_Size    Small
# Name: Supermarket Type1, ...               Tier 2
#
#              Outlet_Type  Item_Outlet_Sales source   Item_Category  \
# 0      Supermarket Type1          3735.1380  train            Food
# 1      Supermarket Type2           443.4228  train          Drinks
# 2      Supermarket Type1          2097.2700  train            Food
# 3          Grocery Store           732.3800  train            Food
# 4      Supermarket Type1           994.7052  train  Non-Consumable
# ...                  ...                ...    ...             ...
# 14199  Supermarket Type1                NaN   test            Food
# 14200  Supermarket Type2                NaN   test            Food
# 14201  Supermarket Type1                NaN   test  Non-Consumable
# 14202  Supermarket Type1                NaN   test            Food
# 14203  Supermarket Type1                NaN   test            Food
#
#        Outlet_Age Item_MRP_Bin
# 0              14         200+
# 1               4         0-50
# 2              14      100-150
# 3              15      150-200
# 4              26       50-100
# ...           ...          ...
# 14199          16      100-150
# 14200           4      150-200
# 14201          11      100-150
# 14202           6         200+
# 14203          11       50-100
#
# [14204 rows x 16 columns]

# %%
data['Item_Visibility_Bin'] = pd.qcut(
    data['Item_Visibility'], 
    q=4, 
    labels=['Low', 'Medium', 'High', 'Very High']
)

# %%
data['Item_MRP_By_Outlet_Type'] = data['Item_MRP'] * data['Outlet_Type'].map({
    'Grocery Store': 1,
    'Supermarket Type1': 2,
    'Supermarket Type2': 3,
    'Supermarket Type3': 4
})

# %% [markdown]
# ENCODING CATEGORICAL VARIABLES

# %%
categorical_features = ['Item_Fat_Content', 'Item_Type', 'Outlet_Identifier',
                       'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type',
                       'Item_Category', 'Outlet_Age_Bin', 'Item_MRP_Bin']

numerical_features = ['Item_Weight', 'Item_Visibility', 'Item_MRP', 
                     'Outlet_Age', 'Item_Visibility_Normalized']

# %%
data_encoded = pd.get_dummies(data, columns=categorical_features, drop_first=True)

# %% [markdown]
# FEATURE SELECTION

# %%
cols_to_drop = ['Item_Identifier', 'Outlet_Establishment_Year', 'source']

# %%
if 'Item_Outlet_Sales' in data_encoded.columns:
    cols_to_drop.append('Item_Outlet_Sales')

# %%
data_encoded
# Out:
#       Item_Identifier  Item_Weight  Item_Visibility  Item_MRP  \
# 0               FDA15         9.30         0.016047  249.8092
# 1               DRC01         5.92         0.019278   48.2692
# 2               FDN15        17.50         0.016760  141.6180
# 3               FDX07        19.20         0.068571  182.0950
# 4               NCD19         8.93         0.059716   53.8614
# ...               ...          ...              ...       ...
# 14199           FDB58        10.50         0.013496  141.3154
# 14200           FDD47         7.60         0.142991  169.1448
# 14201           NCO17        10.00         0.073529  118.7440
# 14202           FDJ26        15.30         0.067836  214.6218
# 14203           FDU37         9.50         0.104720   79.7960
#
#        Outlet_Establishment_Year  Item_Outlet_Sales source  Outlet_Age  \
# 0                           1999          3735.1380  train          14
# 1                           2009           443.4228  train           4
# 2                           1999          2097.2700  train          14
# 3                           1998           732.3800  train          15
# 4                           1987           994.7052  train          26
# ...                          ...                ...    ...         ...
# 14199                       1997                NaN   test          16
# 14200                       2009                NaN   test           4
# 14201                       2002                NaN   test          11
# 14202                       2007                NaN   test           6
# 14203                       2002                NaN   test          11
#
#       Item_Visibility_Bin  Item_MRP_By_Outlet_Type  ...  Item_Category_Food  \
# 0                     Low                 499.6184  ...                True
# 1                     Low                 144.8076  ...               False
# 2                     Low                 283.2360  ...                True
# 3                    High                 182.0950  ...                True
# 4                  Medium                 107.7228  ...               False
# ...                   ...                      ...  ...                 ...
# 14199                 Low                 282.6308  ...                True
# 14200           Very High                 507.4344  ...                True
# 14201                High                 237.4880  ...               False
# 14202                High                 429.2436  ...                True
# 14203           Very High                 159.5920  ...                True
#
#        Item_Category_Non-Consumable  Outlet_Age_Bin_6-10  \
# 0                             False                False
# 1                             False                False
# 2                             False                False
# 3                             False                False
# 4                              True                False
# ...                             ...                  ...
# 14199                         False                False
# 14200                         False                False
# 14201                          True                False
# 14202                         False                 True
# 14203                         False                False
#
#        Outlet_Age_Bin_11-15  Outlet_Age_Bin_16-20  Outlet_Age_Bin_20+  \
# 0                      True                 False               False
# 1                     False                 False               False
# 2                      True                 False               False
# 3                      True                 False               False
# 4                     False                 False                True
# ...                     ...                   ...                 ...
# 14199                 False                  True               False
# 14200                 False                 False               False
# 14201                  True                 False               False
# 14202                 False                 False               False
# 14203                  True                 False               False
#
#        Item_MRP_Bin_50-100  Item_MRP_Bin_100-150  Item_MRP_Bin_150-200  \
# 0                    False                 False                 False
# 1                    False                 False                 False
# 2                    False                  True                 False
# 3                    False                 False                  True
# 4                     True                 False                 False
# ...                    ...                   ...                   ...
# 14199                False                  True                 False
# 14200                False                 False                  True
# 14201                False                  True                 False
# 14202                False                 False                 False
# 14203                 True                 False                 False
#
#        Item_MRP_Bin_200+
# 0                   True
# 1                  False
# 2                  False
# 3                  False
# 4                  False
# ...                  ...
# 14199              False
# 14200              False
# 14201              False
# 14202               True
# 14203              False
#
# [14204 rows x 54 columns]

# %%
data_processed = data_encoded.drop(columns=cols_to_drop)
data_processed
# Out:
#        Item_Weight  Item_Visibility  Item_MRP  Outlet_Age Item_Visibility_Bin  \
# 0             9.30         0.016047  249.8092          14                 Low
# 1             5.92         0.019278   48.2692           4                 Low
# 2            17.50         0.016760  141.6180          14                 Low
# 3            19.20         0.068571  182.0950          15                High
# 4             8.93         0.059716   53.8614          26              Medium
# ...            ...              ...       ...         ...                 ...
# 14199        10.50         0.013496  141.3154          16                 Low
# 14200         7.60         0.142991  169.1448           4           Very High
# 14201        10.00         0.073529  118.7440          11                High
# 14202        15.30         0.067836  214.6218           6                High
# 14203         9.50         0.104720   79.7960          11           Very High
#
#        Item_MRP_By_Outlet_Type  Item_Fat_Content_Regular  Item_Type_Breads  \
# 0                     499.6184                     False             False
# 1                     144.8076                      True             False
# 2                     283.2360                     False             False
# 3                     182.0950                      True             False
# 4                     107.7228                     False             False
# ...                        ...                       ...               ...
# 14199                 282.6308                      True             False
# 14200                 507.4344                      True             False
# 14201                 237.4880                     False             False
# 14202                 429.2436                      True             False
# 14203                 159.5920                      True             False
#
#        Item_Type_Breakfast  Item_Type_Canned  ...  Item_Category_Food  \
# 0                    False             False  ...                True
# 1                    False             False  ...               False
# 2                    False             False  ...                True
# 3                    False             False  ...                True
# 4                    False             False  ...               False
# ...                    ...               ...  ...                 ...
# 14199                False             False  ...                True
# 14200                False             False  ...                True
# 14201                False             False  ...               False
# 14202                False              True  ...                True
# 14203                False              True  ...                True
#
#        Item_Category_Non-Consumable  Outlet_Age_Bin_6-10  \
# 0                             False                False
# 1                             False                False
# 2                             False                False
# 3                             False                False
# 4                              True                False
# ...                             ...                  ...
# 14199                         False                False
# 14200                         False                False
# 14201                          True                False
# 14202                         False                 True
# 14203                         False                False
#
#        Outlet_Age_Bin_11-15  Outlet_Age_Bin_16-20  Outlet_Age_Bin_20+  \
# 0                      True                 False               False
# 1                     False                 False               False
# 2                      True                 False               False
# 3                      True                 False               False
# 4                     False                 False                True
# ...                     ...                   ...                 ...
# 14199                 False                  True               False
# 14200                 False                 False               False
# 14201                  True                 False               False
# 14202                 False                 False               False
# 14203                  True                 False               False
#
#        Item_MRP_Bin_50-100  Item_MRP_Bin_100-150  Item_MRP_Bin_150-200  \
# 0                    False                 False                 False
# 1                    False                 False                 False
# 2                    False                  True                 False
# 3                    False                 False                  True
# 4                     True                 False                 False
# ...                    ...                   ...                   ...
# 14199                False                  True                 False
# 14200                False                 False                  True
# 14201                False                  True                 False
# 14202                False                 False                 False
# 14203                 True                 False                 False
#
#        Item_MRP_Bin_200+
# 0                   True
# 1                  False
# 2                  False
# 3                  False
# 4                  False
# ...                  ...
# 14199              False
# 14200              False
# 14201              False
# 14202               True
# 14203              False
#
# [14204 rows x 50 columns]

# %%
target = train_data['Item_Outlet_Sales'].copy()

# %%
train_idx = data[data['source'] == 'train'].index
test_idx = data[data['source'] == 'test'].index

# Split the processed data
X_train = data_processed.iloc[train_idx]
X_test = data_processed.iloc[test_idx]

# Reattach the target variable to the training set
X_train['Item_Outlet_Sales'] = target.values

print("\nProcessed train shape:", X_train.shape)
print("Processed test shape:", X_test.shape)

# 7. FINAL CHECK
# Check if there are any missing values left
print("\nMissing values in processed train data:")
print(X_train.isnull().sum().sum())

print("\nMissing values in processed test data:")
print(X_test.isnull().sum().sum())

# 8. SAVE PROCESSED DATA
X_train.to_csv('train_processed.csv', index=False)
X_test.to_csv('test_processed.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 5
#       2 test_idx = data[data['source'] == 'test'].index
#       4 # Split the processed data
# ----> 5 X_train = data_processed.iloc[train_idx]
#       6 X_test = data_processed.iloc[test_idx]
#       8 # Reattach the target variable to the training set
#
# NameError: name 'data_processed' is not defined
